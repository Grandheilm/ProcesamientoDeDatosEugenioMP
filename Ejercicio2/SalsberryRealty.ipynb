# %%
import matplotlib
matplotlib.use('TkAgg')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("SalsberryRealty.csv")

print(data.shape)
print(data.head())
# Out:
# (20, 5)
#    Cost  Temp  Insul  Age  Garage
# 0   250    35      3    6       0
# 1   360    29      4   10       1
# 2   165    36      7    3       0
# 3    43    60      6    9       0
# 4    92    65      5    6       0

# %%
X = data[["Temp", "Insul", "Age"]]
y = data['Cost']

# %%
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# %% [markdown]
# 3. Valor de Interseccion

# %%
print('Intersección: ', model.intercept_)
# Out:
# Intersección:  427.1938033196461

# %%
print('Coefcicientes: ', model.coef_)
print('Error Cuadratico de la media: ', mse)
print('Varianza: ', r2)
# Out:
# Coefcicientes:  [ -4.58266263 -14.83086269   6.10103206]
# Error Cuadratico de la media:  2084.7638583181524
# Varianza:  0.8041700664870352

# %% [markdown]
# 4. Estimar para 30°, aislamiento 5", antiguedad 10 años

# %%
Y = model.predict([[30, 5, 10]])
print("El costo de calefaccion estimado es: ", Y)
# Out:
# El costo de calefaccion estimado es:  [276.56993172]
# c:\Users\elyix\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
